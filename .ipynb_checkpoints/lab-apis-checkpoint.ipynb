# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "SECRET"
CLIENT_SECRET = "SECRET"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.1.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (2.32.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (2024.8.30)
# Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)
# Downloading redis-5.1.1-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.3/261.3 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.1.1 spotipy-2.24.0

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#        'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#        'id': '4VIvfOurcf0vuLRxLkGnIG',
#        'name': 'Bradley Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#      'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#      'id': '3edjzMAVB9RYRd4UcZBchx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#        'width': 64}],
#      'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#      'release_date': '2018-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 210200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71813195'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2rbDhOo9Fh61Bbu23T2qCk'},
#     'href': 'https://api.spotify.com/v1/tracks/2rbDhOo9Fh61Bbu23T2qCk',
#     'id': '2rbDhOo9Fh61Bbu23T2qCk',
#     'is_local': False,
#     'name': 'Always Remember Us This Way',
#     'popularity': 82,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#        'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#        'id': '12GqGscKJx3aE4t07u7eVZ',
#        'name': 'Peso Pluma',
#        'type': 'artist',
#        'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#      'href': 'https://api.spotify.com/v1/albums/4jox3ip1I39DFC2B7R5qLH',
#      'id': '4jox3ip1I39DFC2B7R5qLH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732fb583ed96f8f35cbf2897ba',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba',
#        'width': 64}],
#      'name': 'GÉNESIS',
#      'release_date': '2023-06-29',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4jox3ip1I39DFC2B7R5qLH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#       'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#       'id': '12GqGscKJx3aE4t07u7eVZ',
#       'name': 'Peso Pluma',
#       'type': 'artist',
#       'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sbl0NT50roqWvy746MfVf'},
#       'href': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf',
#       'id': '6Sbl0NT50roqWvy746MfVf',
#       'name': 'Gabito Ballesteros',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Sbl0NT50roqWvy746MfVf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#       'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#       'id': '7Gi6gjaWy3DxyilpF1a8Is',
#       'name': 'Junior H',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 212878,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM7282306246'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR'},
#     'href': 'https://api.spotify.com/v1/tracks/7mXuWTczZNxG5EDcjFEuJR',
#     'id': '7mXuWTczZNxG5EDcjFEuJR',
#     'is_local': False,
#     'name': 'LADY GAGA',
#     'popularity': 80,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec439edcef8f1b71e88cfeb7d200db274901123b?cid=6d36d6add5c2480d929fd4a5fb3598b6',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7mXuWTczZNxG5EDcjFEuJR'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#      'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#      'id': '10FLjwfpbxLmW8c25Xyc2N',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#        'width': 64}],
#      'name': 'Die With A Smile',
#      'release_date': '2024-08-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 251667,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72409273'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#     'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#     'id': '2plbrEY59IikOBgBGLjaoe',
#     'is_local': False,
#     'name': 'Die With A Smile',
#     'popularity': 100,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#      'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#      'id': '1jpUMnKpRlng1OJN7LJauV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273613aaa3ae566d9f36008aed0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02613aaa3ae566d9f36008aed0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851613aaa3ae566d9f36008aed0',
#        'width': 64}],
#      'name': 'The Fame',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 237200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70824409'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5R8dQOPq8haW94K7mgERlO'},
#     'href': 'https://api.spotify.com/v1/tracks/5R8dQOPq8haW94K7mgERlO',
#     'id': '5R8dQOPq8haW94K7mgERlO',
#     'is_local': False,
#     'name': 'Poker Face',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5R8dQOPq8haW94K7mgERlO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#      'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#      'id': '6rePArBMb5nLWEaY9aQqL4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa',
#        'width': 64}],
#      'name': 'The Fame Monster (Deluxe Edition)',
#      'release_date': '2009-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 294573,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM70918596'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0SiywuOBRcynK0uKGWdCnn'},
#     'href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#     'id': '0SiywuOBRcynK0uKGWdCnn',
#     'is_local': False,
#     'name': 'Bad Romance',
#     'popularity': 82,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#      'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#      'id': '1jpUMnKpRlng1OJN7LJauV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273613aaa3ae566d9f36008aed0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02613aaa3ae566d9f36008aed0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851613aaa3ae566d9f36008aed0',
#        'width': 64}],
#      'name': 'The Fame',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fObcBw9VM3x7ntWKCYl0z'},
#       'href': 'https://api.spotify.com/v1/artists/7fObcBw9VM3x7ntWKCYl0z',
#       'id': '7fObcBw9VM3x7ntWKCYl0z',
#       'name': "Colby O'Donis",
#       'type': 'artist',
#       'uri': 'spotify:artist:7fObcBw9VM3x7ntWKCYl0z'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 241933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70807646'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2x7MyWybabEz6Y6wvHuwGE'},
#     'href': 'https://api.spotify.com/v1/tracks/2x7MyWybabEz6Y6wvHuwGE',
#     'id': '2x7MyWybabEz6Y6wvHuwGE',
#     'is_local': False,
#     'name': 'Just Dance',
#     'popularity': 74,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2x7MyWybabEz6Y6wvHuwGE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KkMVsxymoNR7hRmBcMttd'},
#      'href': 'https://api.spotify.com/v1/albums/2KkMVsxymoNR7hRmBcMttd',
#      'id': '2KkMVsxymoNR7hRmBcMttd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ba15b951a5cff36133ca5bd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ba15b951a5cff36133ca5bd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ba15b951a5cff36133ca5bd',
#        'width': 64}],
#      'name': 'Born This Way',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2KkMVsxymoNR7hRmBcMttd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 249066,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71104998'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0QkWikH5Z3U0f79T9iuF6c'},
#     'href': 'https://api.spotify.com/v1/tracks/0QkWikH5Z3U0f79T9iuF6c',
#     'id': '0QkWikH5Z3U0f79T9iuF6c',
#     'is_local': False,
#     'name': 'Judas',
#     'popularity': 73,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0QkWikH5Z3U0f79T9iuF6c'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#      'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#      'id': '5maeycU97NHBgwRr2h2A4O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#        'width': 64}],
#      'name': 'Born This Way (Special Edition)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 244760,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71106449'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/11BKm0j4eYoCPPpCONAVwA'},
#     'href': 'https://api.spotify.com/v1/tracks/11BKm0j4eYoCPPpCONAVwA',
#     'id': '11BKm0j4eYoCPPpCONAVwA',
#     'is_local': False,
#     'name': 'Bloody Mary',
#     'popularity': 69,
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:11BKm0j4eYoCPPpCONAVwA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'MY',
#       'MT',
#       'MX',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6DGZdMi124iOOih9GMlhN2'},
#      'href': 'https://api.spotify.com/v1/albums/6DGZdMi124iOOih9GMlhN2',
#      'id': '6DGZdMi124iOOih9GMlhN2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bfd247438980173d32fd5ba8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bfd247438980173d32fd5ba8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bfd247438980173d32fd5ba8',
#        'width': 64}],
#      'name': 'The Fame Monster (Deluxe Edition)',
#      'release_date': '2009-08-05',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:6DGZdMi124iOOih9GMlhN2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
# ...
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 234853,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70905529'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4MfBFhIBXrmqrczjYqasLp'},
#     'href': 'https://api.spotify.com/v1/tracks/4MfBFhIBXrmqrczjYqasLp',
#     'id': '4MfBFhIBXrmqrczjYqasLp',
#     'is_local': False,
#     'name': 'So Happy I Could Die',
#     'popularity': 52,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:4MfBFhIBXrmqrczjYqasLp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#      'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#      'id': '5maeycU97NHBgwRr2h2A4O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#        'width': 64}],
#      'name': 'Born This Way (Special Edition)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 307360,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71106457'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6szOfaZn6H3rZXnUqgJ4R7'},
#     'href': 'https://api.spotify.com/v1/tracks/6szOfaZn6H3rZXnUqgJ4R7',
#     'id': '6szOfaZn6H3rZXnUqgJ4R7',
#     'is_local': False,
#     'name': 'You And I',
#     'popularity': 44,
#     'preview_url': None,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:6szOfaZn6H3rZXnUqgJ4R7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'RW',
#       'TG',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ZUwFxlWo0gwTsvZ6L4Meh'},
#      'href': 'https://api.spotify.com/v1/albums/2ZUwFxlWo0gwTsvZ6L4Meh',
#      'id': '2ZUwFxlWo0gwTsvZ6L4Meh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738093238ec0c71ef7c95c8fb1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028093238ec0c71ef7c95c8fb1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518093238ec0c71ef7c95c8fb1',
#        'width': 64}],
#      'name': 'Joanne (Deluxe)',
#      'release_date': '2016-10-21',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2ZUwFxlWo0gwTsvZ6L4Meh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'RW',
#      'TG',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 196906,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71609731'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2kecdnlyueotEMC8rdNlf6'},
#     'href': 'https://api.spotify.com/v1/tracks/2kecdnlyueotEMC8rdNlf6',
#     'id': '2kecdnlyueotEMC8rdNlf6',
#     'is_local': False,
#     'name': 'Joanne',
#     'popularity': 53,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2kecdnlyueotEMC8rdNlf6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#      'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#      'id': '6rePArBMb5nLWEaY9aQqL4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa',
#        'width': 64}],
#      'name': 'The Fame Monster (Deluxe Edition)',
#      'release_date': '2009-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 249280,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM70918597'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2WgyOP8Z1D6GQYumCwH4Dk'},
#     'href': 'https://api.spotify.com/v1/tracks/2WgyOP8Z1D6GQYumCwH4Dk',
#     'id': '2WgyOP8Z1D6GQYumCwH4Dk',
#     'is_local': False,
#     'name': 'Monster',
#     'popularity': 69,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2WgyOP8Z1D6GQYumCwH4Dk'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 951}}

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#    'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#    'id': '3edjzMAVB9RYRd4UcZBchx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#      'width': 64}],
#    'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#    'release_date': '2018-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 210200,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71813195'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2rbDhOo9Fh61Bbu23T2qCk'},
#   'href': 'https://api.spotify.com/v1/tracks/2rbDhOo9Fh61Bbu23T2qCk',
#   'id': '2rbDhOo9Fh61Bbu23T2qCk',
#   'is_local': False,
#   'name': 'Always Remember Us This Way',
#   'popularity': 82,
#   'preview_url': None,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#      'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#      'id': '12GqGscKJx3aE4t07u7eVZ',
#      'name': 'Peso Pluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#    'href': 'https://api.spotify.com/v1/albums/4jox3ip1I39DFC2B7R5qLH',
#    'id': '4jox3ip1I39DFC2B7R5qLH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732fb583ed96f8f35cbf2897ba',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba',
#      'width': 64}],
#    'name': 'GÉNESIS',
#    'release_date': '2023-06-29',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:4jox3ip1I39DFC2B7R5qLH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#     'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#     'id': '12GqGscKJx3aE4t07u7eVZ',
#     'name': 'Peso Pluma',
#     'type': 'artist',
#     'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sbl0NT50roqWvy746MfVf'},
#     'href': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf',
#     'id': '6Sbl0NT50roqWvy746MfVf',
#     'name': 'Gabito Ballesteros',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Sbl0NT50roqWvy746MfVf'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#     'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#     'id': '7Gi6gjaWy3DxyilpF1a8Is',
#     'name': 'Junior H',
#     'type': 'artist',
#     'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 212878,
#   'explicit': True,
#   'external_ids': {'isrc': 'QM7282306246'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR'},
#   'href': 'https://api.spotify.com/v1/tracks/7mXuWTczZNxG5EDcjFEuJR',
#   'id': '7mXuWTczZNxG5EDcjFEuJR',
#   'is_local': False,
#   'name': 'LADY GAGA',
#   'popularity': 80,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ec439edcef8f1b71e88cfeb7d200db274901123b?cid=6d36d6add5c2480d929fd4a5fb3598b6',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:7mXuWTczZNxG5EDcjFEuJR'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#    'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#    'id': '10FLjwfpbxLmW8c25Xyc2N',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#      'width': 64}],
#    'name': 'Die With A Smile',
#    'release_date': '2024-08-16',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 251667,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72409273'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#   'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#   'id': '2plbrEY59IikOBgBGLjaoe',
#   'is_local': False,
#   'name': 'Die With A Smile',
#   'popularity': 100,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#    'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#    'id': '1jpUMnKpRlng1OJN7LJauV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273613aaa3ae566d9f36008aed0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02613aaa3ae566d9f36008aed0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851613aaa3ae566d9f36008aed0',
#      'width': 64}],
#    'name': 'The Fame',
#    'release_date': '2008-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 237200,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70824409'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5R8dQOPq8haW94K7mgERlO'},
#   'href': 'https://api.spotify.com/v1/tracks/5R8dQOPq8haW94K7mgERlO',
#   'id': '5R8dQOPq8haW94K7mgERlO',
#   'is_local': False,
#   'name': 'Poker Face',
#   'popularity': 76,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5R8dQOPq8haW94K7mgERlO'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#    'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#    'id': '6rePArBMb5nLWEaY9aQqL4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa',
#      'width': 64}],
#    'name': 'The Fame Monster (Deluxe Edition)',
#    'release_date': '2009-11-05',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 294573,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM70918596'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0SiywuOBRcynK0uKGWdCnn'},
#   'href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#   'id': '0SiywuOBRcynK0uKGWdCnn',
#   'is_local': False,
#   'name': 'Bad Romance',
#   'popularity': 82,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#    'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#    'id': '1jpUMnKpRlng1OJN7LJauV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273613aaa3ae566d9f36008aed0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02613aaa3ae566d9f36008aed0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851613aaa3ae566d9f36008aed0',
#      'width': 64}],
#    'name': 'The Fame',
#    'release_date': '2008-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:1jpUMnKpRlng1OJN7LJauV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fObcBw9VM3x7ntWKCYl0z'},
#     'href': 'https://api.spotify.com/v1/artists/7fObcBw9VM3x7ntWKCYl0z',
#     'id': '7fObcBw9VM3x7ntWKCYl0z',
#     'name': "Colby O'Donis",
#     'type': 'artist',
#     'uri': 'spotify:artist:7fObcBw9VM3x7ntWKCYl0z'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 241933,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70807646'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2x7MyWybabEz6Y6wvHuwGE'},
#   'href': 'https://api.spotify.com/v1/tracks/2x7MyWybabEz6Y6wvHuwGE',
#   'id': '2x7MyWybabEz6Y6wvHuwGE',
#   'is_local': False,
#   'name': 'Just Dance',
#   'popularity': 74,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2x7MyWybabEz6Y6wvHuwGE'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2KkMVsxymoNR7hRmBcMttd'},
#    'href': 'https://api.spotify.com/v1/albums/2KkMVsxymoNR7hRmBcMttd',
#    'id': '2KkMVsxymoNR7hRmBcMttd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734ba15b951a5cff36133ca5bd',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024ba15b951a5cff36133ca5bd',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514ba15b951a5cff36133ca5bd',
#      'width': 64}],
#    'name': 'Born This Way',
#    'release_date': '2011-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:2KkMVsxymoNR7hRmBcMttd'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 249066,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71104998'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0QkWikH5Z3U0f79T9iuF6c'},
#   'href': 'https://api.spotify.com/v1/tracks/0QkWikH5Z3U0f79T9iuF6c',
#   'id': '0QkWikH5Z3U0f79T9iuF6c',
#   'is_local': False,
#   'name': 'Judas',
#   'popularity': 73,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:0QkWikH5Z3U0f79T9iuF6c'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#    'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#    'id': '5maeycU97NHBgwRr2h2A4O',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#      'width': 64}],
#    'name': 'Born This Way (Special Edition)',
#    'release_date': '2011-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 244760,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71106449'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/11BKm0j4eYoCPPpCONAVwA'},
#   'href': 'https://api.spotify.com/v1/tracks/11BKm0j4eYoCPPpCONAVwA',
#   'id': '11BKm0j4eYoCPPpCONAVwA',
#   'is_local': False,
#   'name': 'Bloody Mary',
#   'popularity': 69,
#   'preview_url': None,
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:11BKm0j4eYoCPPpCONAVwA'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'MY',
#     'MT',
#     'MX',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6DGZdMi124iOOih9GMlhN2'},
#    'href': 'https://api.spotify.com/v1/albums/6DGZdMi124iOOih9GMlhN2',
#    'id': '6DGZdMi124iOOih9GMlhN2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bfd247438980173d32fd5ba8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bfd247438980173d32fd5ba8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bfd247438980173d32fd5ba8',
#      'width': 64}],
#    'name': 'The Fame Monster (Deluxe Edition)',
#    'release_date': '2009-08-05',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:6DGZdMi124iOOih9GMlhN2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'MY',
#    'MT',
#    'MX',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 274213,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70905526'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4lwavw59UjXUPJZtKNdFYp'},
#   'href': 'https://api.spotify.com/v1/tracks/4lwavw59UjXUPJZtKNdFYp',
#   'id': '4lwavw59UjXUPJZtKNdFYp',
#   'is_local': False,
#   'name': 'Alejandro',
#   'popularity': 70,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:4lwavw59UjXUPJZtKNdFYp'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'RW',
#     'TG',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4sLtOBOzn4s3GDUv3c5oJD'},
#    'href': 'https://api.spotify.com/v1/albums/4sLtOBOzn4s3GDUv3c5oJD',
#    'id': '4sLtOBOzn4s3GDUv3c5oJD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e2d156fdc691f57900134342',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e2d156fdc691f57900134342',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e2d156fdc691f57900134342',
#      'width': 64}],
#    'name': 'A Star Is Born Soundtrack',
#    'release_date': '2018-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 34,
#    'type': 'album',
#    'uri': 'spotify:album:4sLtOBOzn4s3GDUv3c5oJD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#     'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#     'id': '4VIvfOurcf0vuLRxLkGnIG',
#     'name': 'Bradley Cooper',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
# ...
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6DGZdMi124iOOih9GMlhN2'},
#    'href': 'https://api.spotify.com/v1/albums/6DGZdMi124iOOih9GMlhN2',
#    'id': '6DGZdMi124iOOih9GMlhN2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bfd247438980173d32fd5ba8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bfd247438980173d32fd5ba8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bfd247438980173d32fd5ba8',
#      'width': 64}],
#    'name': 'The Fame Monster (Deluxe Edition)',
#    'release_date': '2009-08-05',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:6DGZdMi124iOOih9GMlhN2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'MY',
#    'MT',
#    'MX',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 234853,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM70905529'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4MfBFhIBXrmqrczjYqasLp'},
#   'href': 'https://api.spotify.com/v1/tracks/4MfBFhIBXrmqrczjYqasLp',
#   'id': '4MfBFhIBXrmqrczjYqasLp',
#   'is_local': False,
#   'name': 'So Happy I Could Die',
#   'popularity': 52,
#   'preview_url': None,
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:4MfBFhIBXrmqrczjYqasLp'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5maeycU97NHBgwRr2h2A4O'},
#    'href': 'https://api.spotify.com/v1/albums/5maeycU97NHBgwRr2h2A4O',
#    'id': '5maeycU97NHBgwRr2h2A4O',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a47c0e156ea3cebe37fdcab8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a47c0e156ea3cebe37fdcab8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a47c0e156ea3cebe37fdcab8',
#      'width': 64}],
#    'name': 'Born This Way (Special Edition)',
#    'release_date': '2011-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:5maeycU97NHBgwRr2h2A4O'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 307360,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71106457'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6szOfaZn6H3rZXnUqgJ4R7'},
#   'href': 'https://api.spotify.com/v1/tracks/6szOfaZn6H3rZXnUqgJ4R7',
#   'id': '6szOfaZn6H3rZXnUqgJ4R7',
#   'is_local': False,
#   'name': 'You And I',
#   'popularity': 44,
#   'preview_url': None,
#   'track_number': 16,
#   'type': 'track',
#   'uri': 'spotify:track:6szOfaZn6H3rZXnUqgJ4R7'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'RW',
#     'TG',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2ZUwFxlWo0gwTsvZ6L4Meh'},
#    'href': 'https://api.spotify.com/v1/albums/2ZUwFxlWo0gwTsvZ6L4Meh',
#    'id': '2ZUwFxlWo0gwTsvZ6L4Meh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738093238ec0c71ef7c95c8fb1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028093238ec0c71ef7c95c8fb1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518093238ec0c71ef7c95c8fb1',
#      'width': 64}],
#    'name': 'Joanne (Deluxe)',
#    'release_date': '2016-10-21',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:2ZUwFxlWo0gwTsvZ6L4Meh'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'RW',
#    'TG',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 196906,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71609731'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2kecdnlyueotEMC8rdNlf6'},
#   'href': 'https://api.spotify.com/v1/tracks/2kecdnlyueotEMC8rdNlf6',
#   'id': '2kecdnlyueotEMC8rdNlf6',
#   'is_local': False,
#   'name': 'Joanne',
#   'popularity': 53,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:2kecdnlyueotEMC8rdNlf6'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#    'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#    'id': '6rePArBMb5nLWEaY9aQqL4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa',
#      'width': 64}],
#    'name': 'The Fame Monster (Deluxe Edition)',
#    'release_date': '2009-11-05',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 249280,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM70918597'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2WgyOP8Z1D6GQYumCwH4Dk'},
#   'href': 'https://api.spotify.com/v1/tracks/2WgyOP8Z1D6GQYumCwH4Dk',
#   'id': '2WgyOP8Z1D6GQYumCwH4Dk',
#   'is_local': False,
#   'name': 'Monster',
#   'popularity': 69,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:2WgyOP8Z1D6GQYumCwH4Dk'}]

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 951

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#     'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#     'id': '4VIvfOurcf0vuLRxLkGnIG',
#     'name': 'Bradley Cooper',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#   'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#   'id': '3edjzMAVB9RYRd4UcZBchx',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2',
#     'width': 64}],
#   'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#   'release_date': '2018-10-05',
#   'release_date_precision': 'day',
#   'total_tracks': 19,
#   'type': 'album',
#   'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 210200,
#  'explicit': False,
#  'external_ids': {'isrc': 'USUM71813195'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2rbDhOo9Fh61Bbu23T2qCk'},
#  'href': 'https://api.spotify.com/v1/tracks/2rbDhOo9Fh61Bbu23T2qCk',
#  'id': '2rbDhOo9Fh61Bbu23T2qCk',
#  'is_local': False,
#  'name': 'Always Remember Us This Way',
#  'popularity': 82,
#  'preview_url': None,
#  'track_number': 9,
#  'type': 'track',
#  'uri': 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'}

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '2rbDhOo9Fh61Bbu23T2qCk'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Always Remember Us This Way'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 82

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
artists = ["Bruce Springsteen", "Von Wegen Lisbeth", "Artem Pivovarov"]

# %%
def get_top_tracks(artist):
    result = sp.search(q=f'artist:{artist}', type='artist')
    
    if result['artists']['items']:
        artist_id = result['artists']['items'][0]['id']
        top_tracks_data = sp.artist_top_tracks(artist_id)
        
        top_tracks = [track['name'] for track in top_tracks_data['tracks'][:5]]
        return top_tracks
    else:
        return []

# %%
top_tracks_list = []

# %%
for artist in artists:
    tracks = get_top_tracks(artist)
    top_tracks_list.append(tracks)

# %%
top_tracks_list
# Out:
# [['Dancing In the Dark',
#   "I'm On Fire",
#   'Streets of Philadelphia - Single Edit',
#   'Born in the U.S.A.',
#   'Sandpaper (feat. Bruce Springsteen)'],
#  ['Wenn du tanzt', 'Bitch', 'Meine Kneipe', 'Auf Eis', 'Elon'],
#  ['Барабан', 'Очі', 'О, Панно!', 'Маніфест', 'Думи']]

# %%
def find_related_artists(artist):
    result = sp.search(q=f'artist:{artist}', type='artist')
    
    if result['artists']['items']:
        artist_id = result['artists']['items'][0]['id']
        
        related_artists_data = sp.artist_related_artists(artist_id)
        
        related_artists_list = [related_artist['name'] for related_artist in related_artists_data['artists'][:5]]
        return related_artists_list
    else:
        return []

# %%
related_artists = []

# %%
for artist in artists:
    related = find_related_artists(artist)
    related_artists.append(related)

# %%
related_artists
# Out:
# [['Dire Straits', 'Don Henley', 'Tom Petty', 'Pretenders', 'Van Morrison'],
#  ['Bilderbuch', 'Die Tentakel von Delphi', 'Käptn Peng', 'Faber', 'OK KID'],
#  ['YAKTAK', 'Wellboy', 'KOLA', 'ZLATA OGNEVICH', 'SHUMEI']]

# %%
my_playlist = []

# %%
for artist_group in related_artists:
    for artist in artist_group:
        related_songs = get_top_tracks(artist)
        my_playlist.append(related_songs)

# %%
my_playlist
# Out:
# [[],
#  [],
#  [],
#  ['Sultans Of Swing',
#   'Walk Of Life - Remastered 1996',
#   'Money For Nothing - Remastered 1996',
#   'Brothers In Arms - Remastered 1996',
#   'Romeo And Juliet'],
#  ['The Boys Of Summer',
#   'Leather and Lace - 2016 Remaster',
#   'Dirty Laundry',
#   'The End Of The Innocence',
#   'The Heart Of The Matter'],
#  ["Free Fallin'",
#   "I Won't Back Down",
#   "Runnin' Down A Dream",
#   'Wildflowers',
#   'Love Is A Long Road'],
#  ["I'll Stand by You",
#   'Brass in Pocket - 2018 Remaster',
#   "Don't Get Me Wrong - 2007 Remaster",
#   'Back on the Chain Gang - 2007 Remaster',
#   'Middle of the Road - 2007 Remaster'],
#  ['Brown Eyed Girl',
#   'Into the Mystic - 2013 Remaster',
#   'Days Like This',
#   'Crazy Love - 2013 Remaster',
#   'Moondance - 2013 Remaster'],
#  ['Maschin', 'Bungalow', 'Nahuel Huapi', 'Checkpoint (Nie Game Over)', 'Baba'],
#  ['Gelernt',
#   'Tango im Treibsand',
#   'Sockosophie',
#   'Meister und Idiot',
#   'Der Anfang ist nah'],
#  ['Gelernt',
#   'Tango im Treibsand',
#   'Sockosophie',
#   'Sie mögen sich',
#   'Dank mir'],
#  ['Oh How He Loves You And Me',
#   'Near To The Heart Of God',
#   'Gentle Shepherd',
#   'In This Very Room',
#   'Amazing Grace'],
#  ['Das Letzte',
#   'Gute Menschen',
#   'Es regnet Hirn',
#   'Am Ende',
#   'Stadt ohne Meer'],
#  ['Погляд', 'Порічка', 'Ендорфін', 'Уночі', 'Нижча зростом'],
#  ['Забий', 'Додому', 'Вишнi', 'Стиль', 'Життя'],
#  ['Naa Ready',
#   'Kotha Raja',
#   'Jorthaale',
#   'Adhirudha - From "Mark Antony"',
#   'Jorthaale - From "Rudhran"'],
#  ['Буревіями - 2023 Remastered Version',
#   'Без тебе',
#   'Все невипадково',
#   'Віддаю',
#   'Ми з України'],
#  ['Буревіями - 2023 Remastered Version',
#   'Дзвони',
#   'Стерва',
#   'Біля тополі',
#   'Волосся']]

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Найпопулярніші пісні сьогодення. Обкладинка: Океан Ельзи',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1V3tM4cuX0v'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1V3tM4cuX0v',
#     'id': '37i9dQZF1DX1V3tM4cuX0v',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002bdcf972b3c66a9198cd0cd6a',
#       'width': None}],
#     'name': 'Hot Hits Україна',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAAA67bqVO+EpieoJ4iQyHyyW',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1V3tM4cuX0v/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1V3tM4cuX0v'},
#    {'collaborative': False,
#     'description': 'the beat of your drift',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWWY64wDtewQt'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWY64wDtewQt',
#     'id': '37i9dQZF1DWWY64wDtewQt',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000027dc5028b26eb62f22d31bb1f',
#       'width': None}],
#     'name': 'phonk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwmCQgAAAABvyKelGHQ2o9hJhxUpmtXu',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWY64wDtewQt/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWWY64wDtewQt'},
#    {'collaborative': False,
#     'description': 'Плейлист, з яким ні затори, ні черги не страшні.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9akWvl0BRwK'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9akWvl0BRwK',
#     'id': '37i9dQZF1DX9akWvl0BRwK',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000255e6a8f1623936130a9e9907',
#       'width': None}],
#     'name': 'Ненудно в дорозі',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwPq2gAAAADmhFCG6s5sYsId+OQDmWht',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9akWvl0BRwK/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9akWvl0BRwK'},
#    {'collaborative': False,
#     'description': 'Запальні треки від українських і світових музикантів. Обкладинка: ALEKSEEV\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcU2mDfNlJqd'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcU2mDfNlJqd',
#     'id': '37i9dQZF1DXcU2mDfNlJqd',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002eeb0bdc6032928b9136e680c',
#       'width': None}],
#     'name': 'Танцювальні хіти',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwaWYAAAAADbn80OdaVjKcRvGwPBXLms',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcU2mDfNlJqd/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcU2mDfNlJqd'},
#    {'collaborative': False,
#     'description': 'Затишна музика для прогулянок пожовклим листячком 🍁',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX2X2YHi92QqA'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2X2YHi92QqA',
#     'id': '37i9dQZF1DX2X2YHi92QqA',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002fed51ad2447b47f48bb94986',
#       'width': None}],
#     'name': 'Осінній релакс',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwfdkAAAAABA2v6I0KVjL0eg320zvxiH',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2X2YHi92QqA/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX2X2YHi92QqA'},
#    {'collaborative': False,
#     'description': 'Улюблена музика українською мовою. Обкладинка: alyona alyona\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5ECfKO3L7Vd'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5ECfKO3L7Vd',
#     'id': '37i9dQZF1DX5ECfKO3L7Vd',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002d888013b15a8fc72ca807d32',
#       'width': None}],
#     'name': 'Найкращі пісні солов’їною',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAADSZCG5IFX+ldS8F+An/98f',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5ECfKO3L7Vd/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5ECfKO3L7Vd'},
#    {'collaborative': False,
#     'description': 'Нова музика від Анна Трінчер & CHEEV, SadSvit, Okean Elzy, alyona alyona та інших виконавців!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX69uAEiqiuHZ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX69uAEiqiuHZ',
#     'id': '37i9dQZF1DX69uAEiqiuHZ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026745f7636524f5a559cc125a',
#       'width': None}],
#     'name': "Новинки щоп'ятницi",
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAAASXj4K+SpIC8t7g0r3BbHY',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX69uAEiqiuHZ/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX69uAEiqiuHZ'},
#    {'collaborative': False,
#     'description': 'Спекотні треки літа 2024   🏖️ 💦 🍹',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX86ZB9BGPT0a'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX86ZB9BGPT0a',
#     'id': '37i9dQZF1DX86ZB9BGPT0a',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c945c9c5a0a473b295228df2',
#       'width': None}],
#     'name': 'Хіти Літа 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZsQfNAAAAAA4Z58niytznGmrSUrZ3Xpw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX86ZB9BGPT0a/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX86ZB9BGPT0a'},
#    {'collaborative': False,
#     'description': 'Найпопулярніші українські треки в 2023 році. Обкладинка: SadSvit',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX15i3d3upwXj'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX15i3d3upwXj',
#     'id': '37i9dQZF1DX15i3d3upwXj',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002db8650410609a6f9e53f5cfe',
#       'width': None}],
#     'name': 'Топ українських треків 2023',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZWcrgAAAAACmrZx0T2Kp6P9zcRR8fWI+',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX15i3d3upwXj/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX15i3d3upwXj'},
#    {'collaborative': False,
#     'description': "It's a main pop girl emergency 🆘  Cover: Charli xcx & Ariana Grande",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7YE2tQ4q86h'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7YE2tQ4q86h',
#     'id': '37i9dQZF1DX7YE2tQ4q86h',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000021c228573d64d664a9b6bc90f',
#       'width': None}],
#     'name': 'OBSESSED',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwiiwAAAAAD2Jtv4PR5dt9AXvoZtfPsf',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7YE2tQ4q86h/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX7YE2tQ4q86h'},
#    {'collaborative': False,
#     'description': 'The hottest 50. Cover: The Weeknd',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#     'id': '37i9dQZF1DXcBWIGoYBM5M',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000023cdf32d92f7cc96021e117d6',
#       'width': None}],
#     'name': 'Today’s Top Hits',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
#     'snapshot_id': 'ZwiiwAAAAADe68OdrjiIXZo6xFP4Rmkc',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'},
#    {'collaborative': False,
#     'description': 'Хіти та новинки української рок-музики. Обкладинка: Океан Ельзи\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWUxthdWUs4N4'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUxthdWUs4N4',
#     'id': '37i9dQZF1DWUxthdWUs4N4',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000222ef91a0f937688f4b7f5ee8',
#       'width': None}],
#     'name': 'Український рок',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zv6pxQAAAACd4KeBD74aHM9aNjH1meDr',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUxthdWUs4N4/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWUxthdWUs4N4'},
#    {'collaborative': False,
#     'description': 'Топові новинки української та світової поп-музики. Обкладинка: Charli xcx & Ariana Grande',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5Wynp5mlXCZ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Wynp5mlXCZ',
#     'id': '37i9dQZF1DX5Wynp5mlXCZ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000028e5d49ba2abdb89e6293fa63',
#       'width': None}],
#     'name': 'ТОП ПОП 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAAAczGjbKIV4S7yUiJGVVhUX',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Wynp5mlXCZ/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5Wynp5mlXCZ'},
#    {'collaborative': False,
#     'description': 'Слухай українських виконавиць на повну гучність! Добірка створена спільно з Машею Кондратенко.\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTtjLYc6QFF2'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTtjLYc6QFF2',
#     'id': '37i9dQZF1DWTtjLYc6QFF2',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002485cea1b476e028b236ad607',
#       'width': None}],
#     'name': 'EQUAL Україна',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zvxi0AAAAAB7/OSLw2AYrObkBpO8BZkI',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTtjLYc6QFF2/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWTtjLYc6QFF2'},
#    {'collaborative': False,
#     'description': 'Хіти українського репу. Обкладинка: kavabanga Depo kolibri',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9lOLSAzbbCv'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9lOLSAzbbCv',
#     'id': '37i9dQZF1DX9lOLSAzbbCv',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002d0b8bbd1c2344d60c41f1a64',
#       'width': None}],
#     'name': 'Реп хіти',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAADYMGSbc1zZYm7AZn76ruwO',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9lOLSAzbbCv/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9lOLSAzbbCv'},
#    {'collaborative': False,
#     'description': 'Топ українських поп пісень у 2023 році. Обкладинка: DOROFEEVA',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXm4aFD88nJT'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXm4aFD88nJT',
#     'id': '37i9dQZF1DWXm4aFD88nJT',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002d8e5dcb428accf66b596c992',
#       'width': None}],
#     'name': 'Найкращі пісні солов’їною 2023',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
#     'snapshot_id': 'ZWcrgAAAAAD8TEYO68GMtSdjh29M0XxZ',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXm4aFD88nJT/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWXm4aFD88nJT'},
#    {'collaborative': False,
#     'description': 'The summer needs dance hits 😎☀️',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWZ7eJRBxKzdO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO',
#     'id': '37i9dQZF1DWZ7eJRBxKzdO',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c7ea8e62ee86671eaa4c341c',
#       'width': None}],
#     'name': 'Summer Dance Hits 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZvYtwAAAAACAdBv1XyYSeoxEqkEATA3X',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO/tracks',
#      'total': 120},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWZ7eJRBxKzdO'},
#    {'collaborative': False,
#     'description': 'Найпопулярніші українські артисти 2023. Обкладинка: YAKTAK\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX011xYE6IHiP'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX011xYE6IHiP',
#     'id': '37i9dQZF1DX011xYE6IHiP',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026995d213489fd395502eff32',
#       'width': None}],
#     'name': 'Топ українських артистів 2023',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZWcrgAAAAADHiS2vrIuRDnUQU+w1paYw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX011xYE6IHiP/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX011xYE6IHiP'},
#    {'collaborative': False,
#     'description': 'Музика, щоб відчути себе вдома 🌻 🫶',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3KJK0P0zUOG'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3KJK0P0zUOG',
#     'id': '37i9dQZF1DX3KJK0P0zUOG',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002038e7a2f96fdcb1a4ab17b58',
#       'width': None}],
#     'name': 'ДІМ',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwU0PAAAAAAjShvW0GJbgZudw0ileNdD',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3KJK0P0zUOG/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3KJK0P0zUOG'},
#    {'collaborative': False,
#     'description': 'Українське музичне золото.  Обкладинка: Назарій Яремчук',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5zxOB6DkdZY'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5zxOB6DkdZY',
#     'id': '37i9dQZF1DX5zxOB6DkdZY',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002a86604e7f2bdf7b435e8b828',
#       'width': None}],
#     'name': 'Злиток',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZtCkLQAAAAAMMEbmOXtRYFqg1yB5uzB+',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5zxOB6DkdZY/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5zxOB6DkdZY'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/featured-playlists?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100}}

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# Sunday Morning - Acoustic
# La Vie En Rose
# You Are My Sunshine
# Too Good At Goodbyes - Acoustic
# True Colours
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# September Song - Guitar Acoustic
# Cold Heart - Acoustic
# Collide - Acoustic Version
# I'm Not the Only One - Live from Spotify, London
# Baby One More Time - Recorded at Spotify Studios New York City
# Rockabye - Acoustic Version
# When You Love Someone - Acoustic
# Ain't Nobody (Loves Me Better) - Acoustic
# Wild Love - Acoustic
# Little Talks
# Linger
# Blinding Lights
# Perfect - Acoustic
# What About Us - Acoustic
# Something Just Like This - Acoustic
# Heaven Is a Place on Earth
# 1973 - Acoustic
# Let It Go - James Bay Spotify Session 2015
# Shape of You - Acoustic
# Billie Jean
# Crazy in Love
# Firestone - Live Acoustic Version
# Naked - Acoustic Version
# Fix You - Live
# Slow Dancing in a Burning Room - Acoustic
# Dancing On My Own - Acoustic
# Can't Help Falling in Love
# Summertime Sadness (Acoustic Cover) feat. Keelan Donovan
# Halo
# We Can't Stop - Acoustic
# Chasing Cars
# Price Tag - Acoustic Version
# Kiss Me - AOL Sessions Acoustic Version
# All of Me - Live from Spotify Milan
# Landslide
# Another Love - Live from Spotify (SXSW)
# Mad World - Recorded at Metropolis Studios, London
# Hey Ya - solo version
# City of Stars
# New Rules - Acoustic
# Girls Just Wanna Have Fun - Acoustic
# Ordinary World
# Bizarre Love Triangle - 2014 Remaster
# Bad Day - Acoustic
# Have You Ever Seen The Rain - Recorded at Electric Lady Studios NYC
# U Remind Me - Recorded at Spotify Studios NYC
# I Kissed a Girl
# Too Much To Ask - Acoustic
# IDGAF - Acoustic
# It Aint me - Acoustic
# Wild World - Acoustic Version
# Chandelier - Live from The Village
# Rhythm Inside - Acoustic
# Pretty Girl - Acoustic Version
# Don't Wanna Know - Acoustic Version
# Unchained Melody
# I Wanna Dance with Somebody
# When Doves Cry - Recorded At Spotify Studios NYC
# Cold Water
# I'm the One - Acoustic
# Sugar - Acoustic
# Your Song - Acoustic
# Over the Rainbow
# Sex On Fire
# 2U - Acoustic Version
# Brandy (You're a Fine Girl)
# Silence
# Creep
# Umbrella - Acoustic Version
# Stitches
# Shallow
# She's On My Mind - Guitar Acoustic
# Nervous - Acoustic
# How to Save a Life - Live in Nashville, TN - December 2006
# Crazy - Live Sessions
# Stay
# Starboy - Acoustic
# Send My Love (To Your New Lover) - Live
# Dancing in the Moonlight - Acoustic Version
# Once In a While - Acoustic
# Scars To Your Beautiful
# Closer
# Maps
# Lot To Learn
# XO
# Shut up and Dance
# New Rules
# Perfect Strangers - Acoustic
# Please Keep Loving Me - Acoustic
# Thunder
# There's Nothing Holdin Me Back
# Hello
# Think Before I Talk - Acoustic

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Maroon 5', 'Daniela Andrade', 'Jasmine Thompson', 'Sam Smith', 'Tom Odell', 'James Bay', 'JP Cooper', 'Elton John', 'Dua Lipa', 'Howie Day', 'Ed Sheeran', 'The Mayries', 'James TW', 'Julia Sheer', 'Jon D', 'Freedom Fry', 'Ouvindo', 'Thomas Daniel', 'Missy & Blonde', 'Julia Ross', 'James Blunt', 'The Civil Wars', 'Kygo', 'Conrad Sewell', 'James Arthur', 'John Mayer', 'Calum Scott', 'Kacey Musgraves', 'Megan Davies', 'Keelan Donovan', 'Lotte Kestner', 'Halloran & Kate', 'The Wind and The Wave', 'Jessie J', 'Sixpence None The Richer', 'John Legend', 'Molly Parden', 'Hollow Hum', 'Lily Allen', 'Obadiah Parker', 'Gavin James', 'Joy Williams', 'Frente!', 'Daniel Powter', 'The Lumineers', 'William Fitzsimmons', 'Niall Horan', 'Sara Farell', 'Joanna Wang', 'Sia', 'Becca Adams', 'Lykke Li', 'Rachel Brown', 'Sarah Jarosz', 'Kyle Nachtigal', 'Sunset & Highland', 'Francesco Yates', 'Rita Ora', "Israel Kamakawiwo'ole", 'Alex Cornell', 'Clementine Duo', 'Catey Shaw', 'Reggii', 'Arlo Parks', 'Jaclyn Davies', 'The Hound + The Fox', 'The Fray', 'Madilyn Bailey', 'Leroy Sanchez', 'Isabella Celander', 'Simon Samaeng', "I'm With Her", 'Paul Kowert', 'Toploader', 'Timeflies', 'Tore', 'Colin & Caroline', 'Vivid Color', 'Anna Elizabeth Laube', 'Anchor + Bell', 'Jonas Blue', 'The Freed', 'Q.Z.B', 'Erato', 'Astrid S']

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
sp.featured_playlists()
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Найпопулярніші пісні сьогодення. Обкладинка: Океан Ельзи',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1V3tM4cuX0v'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1V3tM4cuX0v',
#     'id': '37i9dQZF1DX1V3tM4cuX0v',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002bdcf972b3c66a9198cd0cd6a',
#       'width': None}],
#     'name': 'Hot Hits Україна',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAAA67bqVO+EpieoJ4iQyHyyW',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1V3tM4cuX0v/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1V3tM4cuX0v'},
#    {'collaborative': False,
#     'description': 'the beat of your drift',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWWY64wDtewQt'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWY64wDtewQt',
#     'id': '37i9dQZF1DWWY64wDtewQt',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000027dc5028b26eb62f22d31bb1f',
#       'width': None}],
#     'name': 'phonk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwmCQgAAAABvyKelGHQ2o9hJhxUpmtXu',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWY64wDtewQt/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWWY64wDtewQt'},
#    {'collaborative': False,
#     'description': 'Плейлист, з яким ні затори, ні черги не страшні.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9akWvl0BRwK'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9akWvl0BRwK',
#     'id': '37i9dQZF1DX9akWvl0BRwK',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000255e6a8f1623936130a9e9907',
#       'width': None}],
#     'name': 'Ненудно в дорозі',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwPq2gAAAADmhFCG6s5sYsId+OQDmWht',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9akWvl0BRwK/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9akWvl0BRwK'},
#    {'collaborative': False,
#     'description': 'Запальні треки від українських і світових музикантів. Обкладинка: ALEKSEEV\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcU2mDfNlJqd'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcU2mDfNlJqd',
#     'id': '37i9dQZF1DXcU2mDfNlJqd',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002eeb0bdc6032928b9136e680c',
#       'width': None}],
#     'name': 'Танцювальні хіти',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwaWYAAAAADbn80OdaVjKcRvGwPBXLms',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcU2mDfNlJqd/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcU2mDfNlJqd'},
#    {'collaborative': False,
#     'description': 'Затишна музика для прогулянок пожовклим листячком 🍁',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX2X2YHi92QqA'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2X2YHi92QqA',
#     'id': '37i9dQZF1DX2X2YHi92QqA',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002fed51ad2447b47f48bb94986',
#       'width': None}],
#     'name': 'Осінній релакс',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwfdkAAAAABA2v6I0KVjL0eg320zvxiH',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2X2YHi92QqA/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX2X2YHi92QqA'},
#    {'collaborative': False,
#     'description': 'Улюблена музика українською мовою. Обкладинка: alyona alyona\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5ECfKO3L7Vd'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5ECfKO3L7Vd',
#     'id': '37i9dQZF1DX5ECfKO3L7Vd',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002d888013b15a8fc72ca807d32',
#       'width': None}],
#     'name': 'Найкращі пісні солов’їною',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAADSZCG5IFX+ldS8F+An/98f',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5ECfKO3L7Vd/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5ECfKO3L7Vd'},
#    {'collaborative': False,
#     'description': 'Нова музика від Анна Трінчер & CHEEV, SadSvit, Okean Elzy, alyona alyona та інших виконавців!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX69uAEiqiuHZ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX69uAEiqiuHZ',
#     'id': '37i9dQZF1DX69uAEiqiuHZ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026745f7636524f5a559cc125a',
#       'width': None}],
#     'name': "Новинки щоп'ятницi",
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAAASXj4K+SpIC8t7g0r3BbHY',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX69uAEiqiuHZ/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX69uAEiqiuHZ'},
#    {'collaborative': False,
#     'description': 'Спекотні треки літа 2024   🏖️ 💦 🍹',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX86ZB9BGPT0a'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX86ZB9BGPT0a',
#     'id': '37i9dQZF1DX86ZB9BGPT0a',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c945c9c5a0a473b295228df2',
#       'width': None}],
#     'name': 'Хіти Літа 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZsQfNAAAAAA4Z58niytznGmrSUrZ3Xpw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX86ZB9BGPT0a/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX86ZB9BGPT0a'},
#    {'collaborative': False,
#     'description': 'Найпопулярніші українські треки в 2023 році. Обкладинка: SadSvit',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX15i3d3upwXj'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX15i3d3upwXj',
#     'id': '37i9dQZF1DX15i3d3upwXj',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002db8650410609a6f9e53f5cfe',
#       'width': None}],
#     'name': 'Топ українських треків 2023',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZWcrgAAAAACmrZx0T2Kp6P9zcRR8fWI+',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX15i3d3upwXj/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX15i3d3upwXj'},
#    {'collaborative': False,
#     'description': "It's a main pop girl emergency 🆘  Cover: Charli xcx & Ariana Grande",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7YE2tQ4q86h'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7YE2tQ4q86h',
#     'id': '37i9dQZF1DX7YE2tQ4q86h',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000021c228573d64d664a9b6bc90f',
#       'width': None}],
#     'name': 'OBSESSED',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwiiwAAAAAD2Jtv4PR5dt9AXvoZtfPsf',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7YE2tQ4q86h/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX7YE2tQ4q86h'},
#    {'collaborative': False,
#     'description': 'The hottest 50. Cover: The Weeknd',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#     'id': '37i9dQZF1DXcBWIGoYBM5M',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000023cdf32d92f7cc96021e117d6',
#       'width': None}],
#     'name': 'Today’s Top Hits',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
#     'snapshot_id': 'ZwiiwAAAAADe68OdrjiIXZo6xFP4Rmkc',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'},
#    {'collaborative': False,
#     'description': 'Хіти та новинки української рок-музики. Обкладинка: Океан Ельзи\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWUxthdWUs4N4'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUxthdWUs4N4',
#     'id': '37i9dQZF1DWUxthdWUs4N4',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000222ef91a0f937688f4b7f5ee8',
#       'width': None}],
#     'name': 'Український рок',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zv6pxQAAAACd4KeBD74aHM9aNjH1meDr',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUxthdWUs4N4/tracks',
#      'total': 80},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWUxthdWUs4N4'},
#    {'collaborative': False,
#     'description': 'Топові новинки української та світової поп-музики. Обкладинка: Charli xcx & Ariana Grande',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5Wynp5mlXCZ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Wynp5mlXCZ',
#     'id': '37i9dQZF1DX5Wynp5mlXCZ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000028e5d49ba2abdb89e6293fa63',
#       'width': None}],
#     'name': 'ТОП ПОП 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAAAczGjbKIV4S7yUiJGVVhUX',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Wynp5mlXCZ/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5Wynp5mlXCZ'},
#    {'collaborative': False,
#     'description': 'Слухай українських виконавиць на повну гучність! Добірка створена спільно з Машею Кондратенко.\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTtjLYc6QFF2'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTtjLYc6QFF2',
#     'id': '37i9dQZF1DWTtjLYc6QFF2',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002485cea1b476e028b236ad607',
#       'width': None}],
#     'name': 'EQUAL Україна',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'Zvxi0AAAAAB7/OSLw2AYrObkBpO8BZkI',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTtjLYc6QFF2/tracks',
#      'total': 60},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWTtjLYc6QFF2'},
#    {'collaborative': False,
#     'description': 'Хіти українського репу. Обкладинка: kavabanga Depo kolibri',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9lOLSAzbbCv'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9lOLSAzbbCv',
#     'id': '37i9dQZF1DX9lOLSAzbbCv',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002d0b8bbd1c2344d60c41f1a64',
#       'width': None}],
#     'name': 'Реп хіти',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwhAUAAAAADYMGSbc1zZYm7AZn76ruwO',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9lOLSAzbbCv/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9lOLSAzbbCv'},
#    {'collaborative': False,
#     'description': 'Топ українських поп пісень у 2023 році. Обкладинка: DOROFEEVA',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXm4aFD88nJT'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXm4aFD88nJT',
#     'id': '37i9dQZF1DWXm4aFD88nJT',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002d8e5dcb428accf66b596c992',
#       'width': None}],
#     'name': 'Найкращі пісні солов’їною 2023',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
#     'snapshot_id': 'ZWcrgAAAAAD8TEYO68GMtSdjh29M0XxZ',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXm4aFD88nJT/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWXm4aFD88nJT'},
#    {'collaborative': False,
#     'description': 'The summer needs dance hits 😎☀️',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWZ7eJRBxKzdO'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO',
#     'id': '37i9dQZF1DWZ7eJRBxKzdO',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c7ea8e62ee86671eaa4c341c',
#       'width': None}],
#     'name': 'Summer Dance Hits 2024',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZvYtwAAAAACAdBv1XyYSeoxEqkEATA3X',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ7eJRBxKzdO/tracks',
#      'total': 120},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWZ7eJRBxKzdO'},
#    {'collaborative': False,
#     'description': 'Найпопулярніші українські артисти 2023. Обкладинка: YAKTAK\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX011xYE6IHiP'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX011xYE6IHiP',
#     'id': '37i9dQZF1DX011xYE6IHiP',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000026995d213489fd395502eff32',
#       'width': None}],
#     'name': 'Топ українських артистів 2023',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZWcrgAAAAADHiS2vrIuRDnUQU+w1paYw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX011xYE6IHiP/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX011xYE6IHiP'},
#    {'collaborative': False,
#     'description': 'Музика, щоб відчути себе вдома 🌻 🫶',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3KJK0P0zUOG'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3KJK0P0zUOG',
#     'id': '37i9dQZF1DX3KJK0P0zUOG',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002038e7a2f96fdcb1a4ab17b58',
#       'width': None}],
#     'name': 'ДІМ',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZwU0PAAAAAAjShvW0GJbgZudw0ileNdD',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3KJK0P0zUOG/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX3KJK0P0zUOG'},
#    {'collaborative': False,
#     'description': 'Українське музичне золото.  Обкладинка: Назарій Яремчук',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5zxOB6DkdZY'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5zxOB6DkdZY',
#     'id': '37i9dQZF1DX5zxOB6DkdZY',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002a86604e7f2bdf7b435e8b828',
#       'width': None}],
#     'name': 'Злиток',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
#     'public': True,
#     'snapshot_id': 'ZtCkLQAAAAAMMEbmOXtRYFqg1yB5uzB+',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5zxOB6DkdZY/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5zxOB6DkdZY'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/featured-playlists?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100}}

# %%
def get_featured_playlists():
    featured_playlists_data = sp.featured_playlists()
    
    top_playlists = []
    for playlist in featured_playlists_data['playlists']['items'][:5]:
        playlist_info = {
            'name': playlist['name'],
            'id': playlist['id']
        }
        top_playlists.append(playlist_info)
    
    return top_playlists

# %%
top_featured_playlists = get_featured_playlists()
for playlist in top_featured_playlists:
    print(f"Playlist Name: {playlist['name']}, Playlist ID: {playlist['id']}")
# Out:
# Playlist Name: Hot Hits Україна, Playlist ID: 37i9dQZF1DX1V3tM4cuX0v
# Playlist Name: phonk, Playlist ID: 37i9dQZF1DWWY64wDtewQt
# Playlist Name: Ненудно в дорозі, Playlist ID: 37i9dQZF1DX9akWvl0BRwK
# Playlist Name: Танцювальні хіти, Playlist ID: 37i9dQZF1DXcU2mDfNlJqd
# Playlist Name: Осінній релакс, Playlist ID: 37i9dQZF1DX2X2YHi92QqA

# %%
def display_playlist_info(playlist_id):
    playlist_data = sp.playlist(playlist_id)
    
    name = playlist_data['name']
    description = playlist_data['description']
    total_tracks = playlist_data['tracks']['total']

    print(f"Playlist Name: {name}")
    print(f"Description: {description}")
    print(f"Total Tracks: {total_tracks}")

# %%
display_playlist_info('37i9dQZF1DX1V3tM4cuX0v')
# Out:
# Playlist Name: Hot Hits Україна
# Description: Найпопулярніші пісні сьогодення. Обкладинка: Океан Ельзи
# Total Tracks: 50

# %%
tracks = sp.playlist_tracks('37i9dQZF1DX1V3tM4cuX0v')
print("\nFirst 10 Tracks:")
for track in tracks['items'][:10]:
    track_name = track['track']['name']
    print(track_name)
# Out:
# First 10 Tracks:
# Як ніколи
# Обиратиму себе
# Не лякай
# А що?
# Нагадай
# Хартбіт
# Забий
# Барабан
# Гаї шумлять (1913)
# Ендорфін
